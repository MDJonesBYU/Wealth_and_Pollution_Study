# %% [markdown]
# # Basic Data Structure Observations
# ---
# ## Purpose:
# In this notebook we're going to do our first exploration of the EPA, USDA, and Redfin datasets. Eventually, we will combine these three datasets to identify correlations between pollution, indicators of regional wealth, and urbanization levels. To start though, it's important to evaluate each dataset and the potential issues that could arise from using them. These issues could include:
# * **ethical concerns** <br> Such as considering how the data was collected, if/how consent was obtained, how the data will be used, and how it could cause harm or shift the balance of power.  <br><br>
# * **technical concerns**  <br> such as considering the magnitude of the data, it's structure, data reliability, and how missing data should be treated.
#
# As we explore the data, a key ethical concern could involve how the findings would be use to enact legislative change, or adjust public opinion about particular groups. As such, <u>we strictly prohibit the aggregation of senstive population data</u> (race, religion, age, etc) with this study. Likewise this study should not be used to endorse proposed pollution legislation, without substantial supporting evidence from peer-reviewed sources. You should refer to the [*Terms of Use* clause](https://github.com/MDJonesBYU/Wealth_and_Pollution_Study/blob/main/Terms_of_Use)  to understand how this work should and should not be used. Before citing or using this research, you must agree to adhere to our ToU and [copyright limitations](https://github.com/MDJonesBYU/Wealth_and_Pollution_Study/blob/main/License).
#
# ### Package Installation and Versioning Requirments:
# For questions regarding python version, package installations, and other functional requirements, see the *Read Me* file contained [here](https://github.com/MDJonesBYU/Wealth_and_Pollution_Study/blob/main/Read_me/Read_me.txt).
#
# Now, let's review the data structure we have.

# %%
# Import necessary packages: 
import pandas as pd


# Create a function to load the data
def load_base_data(): 
    """This function will load the raw EPA, USDA, and Redfin datasets and return them as a list. 
    """
    df_emissions = pd.read_json("data/nei.json",dtype={'COUNTY FIPS': str, "STATE FIPS": str})
    df_USDA = pd.read_excel("data/Unemployment.xlsx",header=4)
    df_Redfin = pd.read_csv("data/county_market_tracker.tsv000", sep = '\t')
    return(df_emissions, df_USDA, df_Redfin)


# Add a function to count missing data in the datasets (if any)
def check_nan(df): 
    """Checking for null values"""
    return(df.isnull().sum())

# Get the data
df_emissions, df_USDA, df_Redfin = load_base_data()

# Highlight missing data if any
print(check_nan(df_emissions))

# View sample -- starting with emission data
df_emissions.info()
# Out:
# STATE              0
# STATE FIPS         0
# COUNTY             0
# SECTOR             0
# COUNTY FIPS        0
# POLLUTANT          0
# POLLUTANT TYPE     0
# EMISSIONS          0
# UNIT OF MEASURE    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101010 entries, 0 to 101009
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   STATE            101010 non-null  object
#  1   STATE FIPS       101010 non-null  object
#  2   COUNTY           101010 non-null  object
#  3   SECTOR           101010 non-null  object
#  4   COUNTY FIPS      101010 non-null  object
#  5   POLLUTANT        101010 non-null  object
#  6   POLLUTANT TYPE   101010 non-null  object
#  7   EMISSIONS        101010 non-null  int64
#  8   UNIT OF MEASURE  101010 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 6.9+ MB

# %%
# Let's also take a sample to see the data contents
df_emissions.sample(4)
# Out:
#       STATE STATE FIPS       COUNTY  \
# 76984    SD         46    Kingsbury
# 68424    IA         19    Chickasaw
# 42786    VA         51  King George
# 34563    NC         37     Columbus
#
#                                              SECTOR COUNTY FIPS  \
# 76984  Fuel Comb - Comm/Institutional - Natural Gas         077
# 68424    Fuel Comb - Industrial Boilers, ICEs - Oil         037
# 42786   Mobile - On-Road Diesel Heavy Duty Vehicles         099
# 34563           Mobile - Non-Road Equipment - Other         047
#
#              POLLUTANT POLLUTANT TYPE  EMISSIONS UNIT OF MEASURE
# 76984  Carbon Monoxide            CAP          1             TON
# 68424  Carbon Monoxide            CAP          2             TON
# 42786  Carbon Monoxide            CAP         24             TON
# 34563  Carbon Monoxide            CAP         49             TON

# %%
# Okay, so we see 9 columns, including a unique ID (FIPS) for the state and counties in the emissions dataset. 
# Emissions are separated by sector, which could be useful to probe differences across pollution sources. We 
# also have the county name and state abbreviation for each emission source. Since we extracted the data
# directly from EPA's National Emission Inventory (NEI), we know cabron monoxide is the only pollutant 
# considered, and it's always in units of U.S. tons. So we can ignore these columns in the future. 

# Now, the dataframe has no missing values, but that doesn't mean the dataframe contains all 
# counties in the US. We'll check on that for all datasets shortly. Also, while it's not explicitely stated, 
# this is 2020 emission data only. This will be a problem for our USDA data. To explain, let's go ahead and 
# explore that data.

# %%
# Checking the USDA data: 
print(check_nan(df_USDA))

# View sample, starting with emission data
df_USDA.info()
# Out:
# FIPS_Code                                     0
# State                                         0
# Area_Name                                     0
# Rural_Urban_Continuum_Code_2013              58
# Urban_Influence_Code_2013                    58
#                                              ..
# Employed_2022                                 4
# Unemployed_2022                               4
# Unemployment_rate_2022                        4
# Median_Household_Income_2021                 83
# Med_HH_Income_Percent_of_State_Total_2021    84
# Length: 100, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3277 entries, 0 to 3276
# Data columns (total 100 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   FIPS_Code                                  3277 non-null   int64
#  1   State                                      3277 non-null   object
#  2   Area_Name                                  3277 non-null   object
#  3   Rural_Urban_Continuum_Code_2013            3219 non-null   float64
#  4   Urban_Influence_Code_2013                  3219 non-null   float64
#  5   Metro_2013                                 3224 non-null   float64
#  6   Civilian_labor_force_2000                  3270 non-null   float64
#  7   Employed_2000                              3270 non-null   float64
#  8   Unemployed_2000                            3270 non-null   float64
#  9   Unemployment_rate_2000                     3270 non-null   float64
#  10  Civilian_labor_force_2001                  3270 non-null   float64
#  11  Employed_2001                              3270 non-null   float64
#  12  Unemployed_2001                            3270 non-null   float64
#  13  Unemployment_rate_2001                     3270 non-null   float64
#  14  Civilian_labor_force_2002                  3270 non-null   float64
#  15  Employed_2002                              3270 non-null   float64
#  16  Unemployed_2002                            3270 non-null   float64
#  17  Unemployment_rate_2002                     3270 non-null   float64
#  18  Civilian_labor_force_2003                  3270 non-null   float64
#  19  Employed_2003                              3270 non-null   float64
#  20  Unemployed_2003                            3270 non-null   float64
#  21  Unemployment_rate_2003                     3270 non-null   float64
#  22  Civilian_labor_force_2004                  3270 non-null   float64
#  23  Employed_2004                              3270 non-null   float64
#  24  Unemployed_2004                            3270 non-null   float64
#  25  Unemployment_rate_2004                     3270 non-null   float64
#  26  Civilian_labor_force_2005                  3263 non-null   float64
#  27  Employed_2005                              3263 non-null   float64
#  28  Unemployed_2005                            3263 non-null   float64
#  29  Unemployment_rate_2005                     3263 non-null   float64
#  30  Civilian_labor_force_2006                  3263 non-null   float64
#  31  Employed_2006                              3263 non-null   float64
#  32  Unemployed_2006                            3263 non-null   float64
#  33  Unemployment_rate_2006                     3263 non-null   float64
#  34  Civilian_labor_force_2007                  3270 non-null   float64
#  35  Employed_2007                              3270 non-null   float64
#  36  Unemployed_2007                            3270 non-null   float64
#  37  Unemployment_rate_2007                     3270 non-null   float64
#  38  Civilian_labor_force_2008                  3270 non-null   float64
#  39  Employed_2008                              3270 non-null   float64
#  40  Unemployed_2008                            3270 non-null   float64
#  41  Unemployment_rate_2008                     3270 non-null   float64
#  42  Civilian_labor_force_2009                  3270 non-null   float64
#  43  Employed_2009                              3270 non-null   float64
#  44  Unemployed_2009                            3270 non-null   float64
#  45  Unemployment_rate_2009                     3270 non-null   float64
#  46  Civilian_labor_force_2010                  3272 non-null   float64
#  47  Employed_2010                              3272 non-null   float64
#  48  Unemployed_2010                            3272 non-null   float64
#  49  Unemployment_rate_2010                     3272 non-null   float64
#  50  Civilian_labor_force_2011                  3272 non-null   float64
#  51  Employed_2011                              3272 non-null   float64
#  52  Unemployed_2011                            3272 non-null   float64
#  53  Unemployment_rate_2011                     3272 non-null   float64
#  54  Civilian_labor_force_2012                  3272 non-null   float64
#  55  Employed_2012                              3272 non-null   float64
#  56  Unemployed_2012                            3272 non-null   float64
#  57  Unemployment_rate_2012                     3272 non-null   float64
#  58  Civilian_labor_force_2013                  3272 non-null   float64
#  59  Employed_2013                              3272 non-null   float64
#  60  Unemployed_2013                            3272 non-null   float64
#  61  Unemployment_rate_2013                     3272 non-null   float64
#  62  Civilian_labor_force_2014                  3272 non-null   float64
#  63  Employed_2014                              3272 non-null   float64
#  64  Unemployed_2014                            3272 non-null   float64
#  65  Unemployment_rate_2014                     3272 non-null   float64
#  66  Civilian_labor_force_2015                  3272 non-null   float64
#  67  Employed_2015                              3272 non-null   float64
#  68  Unemployed_2015                            3272 non-null   float64
#  69  Unemployment_rate_2015                     3272 non-null   float64
#  70  Civilian_labor_force_2016                  3272 non-null   float64
#  71  Employed_2016                              3272 non-null   float64
#  72  Unemployed_2016                            3272 non-null   float64
#  73  Unemployment_rate_2016                     3272 non-null   float64
#  74  Civilian_labor_force_2017                  3272 non-null   float64
#  75  Employed_2017                              3272 non-null   float64
#  76  Unemployed_2017                            3272 non-null   float64
#  77  Unemployment_rate_2017                     3272 non-null   float64
#  78  Civilian_labor_force_2018                  3272 non-null   float64
#  79  Employed_2018                              3272 non-null   float64
#  80  Unemployed_2018                            3272 non-null   float64
#  81  Unemployment_rate_2018                     3272 non-null   float64
#  82  Civilian_labor_force_2019                  3272 non-null   float64
#  83  Employed_2019                              3272 non-null   float64
#  84  Unemployed_2019                            3272 non-null   float64
#  85  Unemployment_rate_2019                     3272 non-null   float64
#  86  Civilian_labor_force_2020                  3194 non-null   float64
#  87  Employed_2020                              3194 non-null   float64
#  88  Unemployed_2020                            3194 non-null   float64
#  89  Unemployment_rate_2020                     3194 non-null   float64
#  90  Civilian_labor_force_2021                  3273 non-null   float64
#  91  Employed_2021                              3273 non-null   float64
#  92  Unemployed_2021                            3273 non-null   float64
#  93  Unemployment_rate_2021                     3273 non-null   float64
#  94  Civilian_labor_force_2022                  3273 non-null   float64
#  95  Employed_2022                              3273 non-null   float64
#  96  Unemployed_2022                            3273 non-null   float64
#  97  Unemployment_rate_2022                     3273 non-null   float64
#  98  Median_Household_Income_2021               3194 non-null   float64
#  99  Med_HH_Income_Percent_of_State_Total_2021  3193 non-null   float64
# dtypes: float64(97), int64(1), object(2)
# memory usage: 2.5+ MB

# %%
df_USDA.sample(3)
# Out:
#       FIPS_Code State          Area_Name  Rural_Urban_Continuum_Code_2013  \
# 783       18133    IN  Putnam County, IN                              1.0
# 3197      56045    WY  Weston County, WY                              7.0
# 406       13005    GA   Bacon County, GA                              7.0
#
#       Urban_Influence_Code_2013  Metro_2013  Civilian_labor_force_2000  \
# 783                         1.0         1.0                    17100.0
# 3197                        9.0         0.0                     3284.0
# 406                         9.0         0.0                     4641.0
#
#       Employed_2000  Unemployed_2000  Unemployment_rate_2000  ...  \
# 783         16609.0            491.0                     2.9  ...
# 3197         3147.0            137.0                     4.2  ...
# 406          4431.0            210.0                     4.5  ...
#
#       Civilian_labor_force_2021  Employed_2021  Unemployed_2021  \
# 783                     16514.0        15960.0            554.0
# 3197                     3718.0         3595.0            123.0
# 406                      4830.0         4673.0            157.0
#
#       Unemployment_rate_2021  Civilian_labor_force_2022  Employed_2022  \
# 783                      3.4                    16999.0        16475.0
# 3197                     3.3                     3792.0         3691.0
# 406                      3.3                     4879.0         4736.0
#
#       Unemployed_2022  Unemployment_rate_2022  Median_Household_Income_2021  \
# 783             524.0                     3.1                       61223.0
# 3197            101.0                     2.7                       62509.0
# 406             143.0                     2.9                       43154.0
#
#       Med_HH_Income_Percent_of_State_Total_2021
# 783                                        97.6
# 3197                                       94.0
# 406                                        64.9
#
# [3 rows x 100 columns]

# %%
# So there's a lot to unpack here. First, we have lots of columns that repeat variables across different years. 
# Now there are some really useful features in this dataset including income, unemployment rates, labor force
# size, location, and rural/urban designation code (Continuum Code). 

# After a few minutes some issues should be apparent though. For one, we don't have income data for 2020, and
# the last rural continuum code record (a tag for population density) was taken in 2013. These variables could
# really add depth to our analysis. 

# Since we could not find readily available data to compensate here, we plan to use both of these variables, but
# there's some pretty big assumptions here: 
# 1. We assume income changes between 2020 and 2021 are neglgible down to the county level. For some counties this 
#    could be vastly different from reality given the COVID pandemic's impact on local economies. 
# 2. We assume the rural urban continuum is reasonably close to what it was in 2013. Again this could be an issue 
#    as some regions substantial growth during this period, like Austin TX while other areas had swaths of 
#    emigration (like Edenville, MI where a dam breakage forced residents to leave).

# %%
# Before we dive further into this, let's review the Redfin dataset

# Checking the USDA data: 
print(check_nan(df_Redfin))

# View sample -- starting with emission data
df_Redfin.info()
# Out:
# period_begin                           0
# period_end                             0
# period_duration                        0
# region_type                            0
# region_type_id                         0
# table_id                               0
# is_seasonally_adjusted                 0
# region                                 0
# city                              563122
# state                                  0
# state_code                             0
# property_type                          0
# property_type_id                       0
# median_sale_price                    685
# median_sale_price_mom              52383
# median_sale_price_yoy              69332
# median_list_price                  43920
# median_list_price_mom              81940
# median_list_price_yoy              98455
# median_ppsf                         7395
# median_ppsf_mom                    58352
# median_ppsf_yoy                    75335
# median_list_ppsf                   44644
# median_list_ppsf_mom               82833
# median_list_ppsf_yoy               99359
# homes_sold                           679
# homes_sold_mom                     52377
# homes_sold_yoy                     69325
# pending_sales                      79883
# pending_sales_mom                 125130
# pending_sales_yoy                 142945
# new_listings                       44898
# new_listings_mom                   82938
# new_listings_yoy                   99747
# inventory                          22906
# inventory_mom                      66101
# inventory_yoy                      84719
# months_of_supply                   14964
# months_of_supply_mom               58355
# months_of_supply_yoy               76113
# median_dom                          8797
# median_dom_mom                     60417
# median_dom_yoy                     77922
# avg_sale_to_list                    7931
# avg_sale_to_list_mom               59324
# avg_sale_to_list_yoy               76299
# sold_above_list                     5520
# sold_above_list_mom                57022
# sold_above_list_yoy                74024
# price_drops                       237761
# price_drops_mom                   264795
# price_drops_yoy                   300991
# off_market_in_two_weeks            66963
# off_market_in_two_weeks_mom       113200
# off_market_in_two_weeks_yoy       131904
# parent_metro_region                    0
# parent_metro_region_metro_code    115288
# last_updated                           0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563122 entries, 0 to 563121
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   period_begin                    563122 non-null  object
#  1   period_end                      563122 non-null  object
#  2   period_duration                 563122 non-null  int64
#  3   region_type                     563122 non-null  object
#  4   region_type_id                  563122 non-null  int64
#  5   table_id                        563122 non-null  int64
#  6   is_seasonally_adjusted          563122 non-null  object
#  7   region                          563122 non-null  object
#  8   city                            0 non-null       float64
#  9   state                           563122 non-null  object
#  10  state_code                      563122 non-null  object
#  11  property_type                   563122 non-null  object
#  12  property_type_id                563122 non-null  int64
#  13  median_sale_price               562437 non-null  float64
#  14  median_sale_price_mom           510739 non-null  float64
#  15  median_sale_price_yoy           493790 non-null  float64
#  16  median_list_price               519202 non-null  float64
#  17  median_list_price_mom           481182 non-null  float64
#  18  median_list_price_yoy           464667 non-null  float64
#  19  median_ppsf                     555727 non-null  float64
#  20  median_ppsf_mom                 504770 non-null  float64
#  21  median_ppsf_yoy                 487787 non-null  float64
#  22  median_list_ppsf                518478 non-null  float64
#  23  median_list_ppsf_mom            480289 non-null  float64
#  24  median_list_ppsf_yoy            463763 non-null  float64
#  25  homes_sold                      562443 non-null  float64
#  26  homes_sold_mom                  510745 non-null  float64
#  27  homes_sold_yoy                  493797 non-null  float64
#  28  pending_sales                   483239 non-null  float64
#  29  pending_sales_mom               437992 non-null  float64
#  30  pending_sales_yoy               420177 non-null  float64
#  31  new_listings                    518224 non-null  float64
#  32  new_listings_mom                480184 non-null  float64
#  33  new_listings_yoy                463375 non-null  float64
#  34  inventory                       540216 non-null  float64
#  35  inventory_mom                   497021 non-null  float64
#  36  inventory_yoy                   478403 non-null  float64
#  37  months_of_supply                548158 non-null  float64
#  38  months_of_supply_mom            504767 non-null  float64
#  39  months_of_supply_yoy            487009 non-null  float64
#  40  median_dom                      554325 non-null  float64
#  41  median_dom_mom                  502705 non-null  float64
#  42  median_dom_yoy                  485200 non-null  float64
#  43  avg_sale_to_list                555191 non-null  float64
#  44  avg_sale_to_list_mom            503798 non-null  float64
#  45  avg_sale_to_list_yoy            486823 non-null  float64
#  46  sold_above_list                 557602 non-null  float64
#  47  sold_above_list_mom             506100 non-null  float64
#  48  sold_above_list_yoy             489098 non-null  float64
#  49  price_drops                     325361 non-null  float64
#  50  price_drops_mom                 298327 non-null  float64
#  51  price_drops_yoy                 262131 non-null  float64
#  52  off_market_in_two_weeks         496159 non-null  float64
#  53  off_market_in_two_weeks_mom     449922 non-null  float64
#  54  off_market_in_two_weeks_yoy     431218 non-null  float64
#  55  parent_metro_region             563122 non-null  object
#  56  parent_metro_region_metro_code  447834 non-null  float64
#  57  last_updated                    563122 non-null  object
# dtypes: float64(44), int64(4), object(10)
# memory usage: 249.2+ MB

# %%
df_Redfin.sample(3)
# Out:
#        period_begin period_end  period_duration region_type  region_type_id  \
# 499792     1/1/2017  1/31/2017               30      county               5
# 552999     7/1/2018  7/31/2018               30      county               5
# 57910      8/1/2015  8/31/2015               30      county               5
#
#         table_id is_seasonally_adjusted              region  city      state  \
# 499792      1300                      f     Knox County, ME   NaN      Maine
# 552999      2744                      f     Hays County, TX   NaN      Texas
# 57910       3170                      f  Calumet County, WI   NaN  Wisconsin
#
#         ... sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# 499792  ...            0.023256        0.11         0.038571         0.030078
# 552999  ...            0.257143         NaN              NaN              NaN
# 57910   ...                 NaN         NaN              NaN              NaN
#
#         off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 499792                 0.133333                     0.008333
# 552999                 0.500000                     0.000000
# 57910                       NaN                          NaN
#
#         off_market_in_two_weeks_yoy         parent_metro_region  \
# 499792                    -0.097436  Maine nonmetropolitan area
# 552999                    -0.214286                  Austin, TX
# 57910                           NaN                Appleton, WI
#
#         parent_metro_region_metro_code    last_updated
# 499792                             NaN  1/9/2022 14:29
# 552999                         12420.0  1/9/2022 14:29
# 57910                          11540.0  1/9/2022 14:29
#
# [3 rows x 58 columns]

# %% [markdown]
# Okay, so at a high-level we see that the Redfin dataset provides information on sale price, property type,
# location, number of listings, and the period when the sale occured. Notably, the state name is not
# abbreviated and we aren't given any FIPs to connect to the other datasets, so that's going to be
# an issue down the road. We also only want 2021 data (since our income data is from the same time period,
# and we assume emissions are the same in 2020 and 2021).
#
# Now that we've scratched the surface, we'd like to see if we can make more sense of the data graphically, so we can understand how factors like income, pollution, unemployment, and sale prices are distributed.
#
# To do this graphically, we need to some light data cleaning and grouping, which is covered in the next notebook.

# %% [markdown]
# ### End of Notebook

# %% [markdown]
# Next notebook: Data_manipulation
#
#
# *Note: to limit the number of functions duplicated, all codebook functions will be saved in py files that can be imported to execute.*
#
# ---
